# %%
import os
if "HADOOP_CONF_DIR" in os.environ:
    del os.environ["HADOOP_CONF_DIR"]

# %%
"HADOOP_CONF_DIR" in os.environ
# Out:
# False

# %%
import json
import time
import random
from kafka import KafkaConsumer
from tqdm import tqdm
import socket
from pyspark import SparkConf, SparkContext, SQLContext
from pyspark.sql import SparkSession
from pyspark.sql.types import BooleanType, IntegerType, LongType, StringType, ArrayType, FloatType, StructType, StructField, TimestampType
from pyspark.sql.functions import *
from pyspark.sql.functions import pandas_udf
from pyspark.sql.functions import PandasUDFType
from jinja2 import Environment, FileSystemLoader


# setting constants
APP_NAME = "consume"
NORMALIZED_APP_NAME = APP_NAME.replace('/', '_').replace(':', '_')

APPS_TMP_DIR = os.path.join(os.getcwd(), "tmp")
APPS_CONF_DIR = os.path.join(os.getcwd(), "conf")
APPS_LOGS_DIR = os.path.join(os.getcwd(), "logs")
LOG4J_PROP_FILE = os.path.join(APPS_CONF_DIR, "pyspark-log4j-{}.properties".format(NORMALIZED_APP_NAME))
LOG_FILE = os.path.join(APPS_LOGS_DIR, 'pyspark-{}.log'.format(NORMALIZED_APP_NAME))
EXTRA_JAVA_OPTIONS = "-Dlog4j.configuration=file://{} -Dspark.hadoop.dfs.replication=1 -Dhttps.protocols=TLSv1.0,TLSv1.1,TLSv1.2,TLSv1.3"\
    .format(LOG4J_PROP_FILE)

LOCAL_IP = socket.gethostbyname(socket.gethostname())

# preparing configuration files from templates
for directory in [APPS_CONF_DIR, APPS_LOGS_DIR, APPS_TMP_DIR]:
    if not os.path.exists(directory):
        os.makedirs(directory)

env = Environment(loader=FileSystemLoader('/opt'))
template = env.get_template("pyspark_log4j.properties.template")
template\
    .stream(logfile=LOG_FILE)\
    .dump(LOG4J_PROP_FILE)

# run spark
spark = SparkSession\
    .builder\
    .appName(APP_NAME)\
    .master("k8s://https://10.32.7.103:6443")\
    .config("spark.driver.host", LOCAL_IP)\
    .config("spark.driver.bindAddress", "0.0.0.0")\
    .config("spark.executor.instances", "2")\
    .config("spark.executor.cores", '3')\
    .config("spark.memory.fraction", "0.8")\
    .config("spark.memory.storageFraction", "0.6")\
    .config("spark.executor.memory", '3g')\
    .config("spark.driver.memory", "3g")\
    .config("spark.driver.maxResultSize", "1g")\
    .config("spark.kubernetes.memoryOverheadFactor", "0.3")\
    .config("spark.driver.extraJavaOptions", EXTRA_JAVA_OPTIONS)\
    .config("spark.kubernetes.namespace", "sburmistrova-266294")\
    .config("spark.kubernetes.driver.label.appname", APP_NAME)\
    .config("spark.kubernetes.executor.label.appname", APP_NAME)\
    .config("spark.kubernetes.container.image", "node03.st:5000/spark-executor:sburmistrova-266294")\
    .config("spark.local.dir", "/tmp/spark")\
    .config("spark.driver.extraClassPath", "/home/jovyan/shared-data/my-project-name-jar-with-dependencies.jar")\
    .config("spark.executor.extraClassPath", "/home/jovyan/shared-data/my-project-name-jar-with-dependencies.jar")\
    .config("spark.kubernetes.executor.volumes.emptyDir.spark-local-dir-tmp-spark.mount.path", "/tmp/spark")\
    .config("spark.kubernetes.executor.volumes.emptyDir.spark-local-dir-tmp-spark.mount.readOnly", "false")\
    .config("spark.kubernetes.executor.volumes.hostPath.depdir.mount.path", "/home/jovyan/shared-data")\
    .config("spark.kubernetes.executor.volumes.hostPath.depdir.options.path", "/nfs/shared")\
    .config("spark.kubernetes.executor.volumes.hostPath.depdir.options.type", "Directory")\
    .config("spark.kubernetes.executor.volumes.hostPath.depdir.mount.readOnly", "false")\
    .getOrCreate()

# printing important urls and paths
print("Web UI: {}".format(spark.sparkContext.uiWebUrl))
print("\nlog4j file: {}".format(LOG4J_PROP_FILE))
print("\ndriver log file: {}".format(LOG_FILE))
# Out:
# Web UI: http://10.128.5.219:4041
#
# log4j file: /home/jovyan/nfs-home/conf/pyspark-log4j-consume.properties
#
# driver log file: /home/jovyan/nfs-home/logs/pyspark-consume.log

# %%
import json
import time
import random
from kafka import KafkaProducer
from tqdm import tqdm

# %%
from pyspark.ml.feature import RegexTokenizer
import nltk
nltk.data.path.append("/home/jovyan/nltk_data")
from nltk.corpus import stopwords

# %%
schema = StructType()\
        .add("user_id", LongType())\
        .add("text", StringType())\
        .add("timestamp", TimestampType())

# %%
df = spark.readStream \
    .format("kafka")\
    .option("kafka.bootstrap.servers", "kafka-svc:9092")\
    .option("subscribe", "posts")\
    .load()\
    .select(from_json(col("value").cast("string"), schema).alias("data")).select("data.*")

# %%
profile_df = spark.read.json("/home/jovyan/shared-data/bigdata20/followers_info.json")\
.select(col("id").alias("user_id"), (when(col("sex") == lit(1), lit("F"))
        .when(col("sex") == lit(2), lit("M")).otherwise(lit(None))).alias("sex"),
        (months_between(current_date(), concat_ws( "-", regexp_extract(col("bdate"), r"(\d{1,2})\.(\d{1,2})\.(\d{4})", 3).cast("int"), 
        regexp_extract(col("bdate"), r"(\d{1,2})\.(\d{1,2})\.(\d{4})", 2).cast("int"), 
        regexp_extract(col("bdate"), r"(\d{1,2})\.(\d{1,2})\.(\d{4})", 1).cast("int")).cast("date")) / lit(12)).cast("int").alias("age"))
profile_df.show(5)
# Out:
# +-------+---+----+
# |user_id|sex| age|
# +-------+---+----+
# |     34|  F|null|
# |    102|  F|null|
# |    175|  M|null|
# |    243|  F|  34|
# |    533|  M|  32|
# +-------+---+----+
# only showing top 5 rows

# %%
user_post_df = df.join(broadcast(profile_df), ["user_id"])\
    .select("user_id", "sex", "age", "text", "timestamp")
user_post_df.printSchema()
# Out:
# root
#  |-- user_id: long (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- text: string (nullable = true)
#  |-- timestamp: timestamp (nullable = true)

# %%
import string
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
pattern_punct = string.punctuation+ "\[\]\d]"
pattern_url = "http[s]?://\S+|www\.\S+"
ru_stopwords = stopwords.words('russian')
regexTokenizer = RegexTokenizer(inputCol="cleaned", outputCol="tokens", pattern=r"\s+")

# %%
@udf(returnType=ArrayType(StringType()))
def preprocess_udf(tokens):
    return [word for word in tokens if word not in ru_stopwords]

# %%
def explode_words(df):
    return regexTokenizer.transform(df.withColumn("cleaned", \
        regexp_replace(regexp_replace("text", pattern_url, " "), pattern_punct, " ")))\
        .withColumn("finished", preprocess_udf("tokens"))\
        .withColumn("word", explode("finished"))\
        .drop("text", "cleaned", "tokens", "finished")

# %%
result = explode_words(user_post_df).withColumn("age_group", 
        when(col("age").isNull() | (col("age") < lit(18)), lit("0-18"))
        .when(col("age").between(lit(18), lit(26)), lit("18-27"))
        .when(col("age").between(lit(27), lit(39)), lit("27-40"))
        .when(col("age").between(lit(40), lit(59)), lit("40-60"))
        .when(col("age") >= 60, lit("60")))
#         .withWatermark(eventTime = 'timestamp', delayThreshold = '1 hour')\
#         .groupBy('age_group', 'sex', window(timeColumn = 'timestamp', windowDuration = '1 hour')).count()

# %%
result.printSchema()
# Out:
# root
#  |-- user_id: long (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- word: string (nullable = true)
#  |-- age_group: string (nullable = true)

# %%
# result=exploded_df.withWatermark(eventTime = 'timestamp', delayThreshold = '1 hour')\
#     .groupBy('age_group', 'sex', window(timeColumn = 'timestamp', windowDuration = '1 hour')).count()

# %%
def get_topic_list(df: DataFrame) -> list:
    topic_list = list()
    for sex in ("F", "M"):
        for age_group in ("18", "18-27", "27-40", "40-60", "60"):
            for dur in ("1 hour", "1 day", "1 week"):
                dur_w = dur.replace(' ', '')
                topic_name = f"topic_{sex}_{age_group}_{dur_w}"
                print(topic_name)
                topic = df\
                    .where(f"sex = '{sex}' and age_group = '{age_group}'")\
                    .withWatermark(eventTime = 'timestamp', delayThreshold = dur)\
                    .groupBy(window(timeColumn = 'timestamp', windowDuration = dur), "sex", "age_group").count()\
                    .selectExpr(f"CAST (count AS STRING) AS key", "to_json(struct(*)) AS value")\
                    .writeStream\
                    .outputMode("complete")\
                    .format("kafka")\
                    .option("kafka.bootstrap.servers", "kafka-svc:9092")\
                    .option("topic", topic_name)\
                    .option("checkpointLocation", os.path.join(APPS_TMP_DIR, topic_name))
                topic_dict = dict(topic=topic, sex=sex, age_group=age_group, dur=dur)
                topic_list.append(topic_dict)
    return topic_list

# %%
topics = get_topic_list(result)
# Out:
# topic_F_18_1hour
# topic_F_18_1day
# topic_F_18_1week
# topic_F_18-27_1hour
# topic_F_18-27_1day
# topic_F_18-27_1week
# topic_F_27-40_1hour
# topic_F_27-40_1day
# topic_F_27-40_1week
# topic_F_40-60_1hour
# topic_F_40-60_1day
# topic_F_40-60_1week
# topic_F_60_1hour
# topic_F_60_1day
# topic_F_60_1week
# topic_M_18_1hour
# topic_M_18_1day
# topic_M_18_1week
# topic_M_18-27_1hour
# topic_M_18-27_1day
# topic_M_18-27_1week
# topic_M_27-40_1hour
# topic_M_27-40_1day
# topic_M_27-40_1week
# topic_M_40-60_1hour
# topic_M_40-60_1day
# topic_M_40-60_1week
# topic_M_60_1hour
# topic_M_60_1day
# topic_M_60_1week

# %%
for topic in topics:
    topic["topic_start"] = topic["topic"].start()

# %%
for topic in topics:
    print(topic["topic_start"].status)
# Out:
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Writing offsets to log', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Writing offsets to log', 'isDataAvailable': False, 'isTriggerActive': True}
# {'message': 'Initializing sources', 'isDataAvailable': False, 'isTriggerActive': False}

# %%
# spark.stop()

# %%
consumer = KafkaConsumer(bootstrap_servers=['kafka-svc:9092'],
                         group_id="jupyter",
                         session_timeout_ms=10000,
                         enable_auto_commit=False,
                         auto_offset_reset='earliest',
                         )
consumer.subscribe(topics='topic_M_18-27_1day')

for msg in consumer:
    print(msg.value.decode('utf-8'))
# Out:
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"сделал)","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"#gcam","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"что,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"мотивации)","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"#february","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"-","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"#snapseed","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"#winter","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"странное","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"обещал","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"#mi5","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"#hdr","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"видео","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"которая","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"шаферан","count":4}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"закрывали","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"инициатив","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"ссср","count":5}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"днепропетровской","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"44-й","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"хочу","count":6}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"киноинициативы","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"поясню,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"композитора","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"созданная","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"лица","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"академии","count":4}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"*","count":5}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"пододеяльники","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"(четырежды","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"играл","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"неё!","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"времени»","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"смирнова","count":3}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"баллотировался","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"героя","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"признан","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"сломаны","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"недаром","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"долгого","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"стал!!!","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"исторической","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"крымской","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"сломана","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"информацию","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"популярная","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"прикусывал","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"того,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"личность","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"500","count":2}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"понадобится","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"донском","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"телевизионных","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"tv-персона,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"норвежский","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"диалог\".","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"валентина","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"близким","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"норвежской","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"знакомым","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"дарим","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"разных","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"высоты","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"целей.","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"«приват»,","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"получите:","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"различных","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"окрылял,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"объединения","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"именем","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"ma","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"(1984)","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"годов","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"10—11-го","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"дееспособность.","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"смоленском.","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"иностранным","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"\"единая","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"еее,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"россии,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"шаферана","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"является","count":5}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"первый","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"31","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"увеличилось,","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"которые","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"специальности","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"нато.","count":2}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"#зимаспб","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"комок","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"года)","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"студии,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"лет,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"почётная","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"(настоящее","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"молодёжными","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"\"international","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"должны","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"психологического","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"song","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"like","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"советская","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"журналист","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"человек,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"соответствует","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"закончилось","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"утомил","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"багратионович","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"мировое","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"доверенное","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"совета","count":5}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"«защитнику","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"посла","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"наград,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"subscribe","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"нидерланды,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"дочери","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"264-му","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"травма,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"террористов","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"московской","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"vk.com/app4236781_388752998#cw3","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"влиятельных","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"воздухе","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"\"евроаск\"","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"первую","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"оперный","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"времени.","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"музыкальном","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"юридически","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"просьба","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"крупные","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"киносоюза.","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"сломанный","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"совместной","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"года","count":23}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"песней","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"тихо.","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"старшего","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"чудеса.","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"zenome","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"«ненаглядная","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"твоя","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"купить","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"1952","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"музыкальных","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"люксембург),","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"твёрдого","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"60-летию","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"«всё","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"преступлений,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"руководитель","count":3}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"нос.","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"конкурса","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"марковича","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"россии.","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"радуев","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"солист","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"балтики,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"выставок.","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"шаляпин","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"24","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"открытого","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"еврейской","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"второго","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"съездить","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"спасибо,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"«моя","count":3}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"ложится","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"#плакетка","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"складываться","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"(бельгия,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"вопросам","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"документальное","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"журнала","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"напишу","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"брейтбургом","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"любимой","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"#снежнаязима","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"оперное","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"программе","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"двадцать","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"отдыхаю","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"анализа","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"вернули","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"кинорежиссёров.","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"российской","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"определяет","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"перенес","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"блондинка,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"вице-президент","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"республики","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"юстинаса","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"советник","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"введенском","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"всесоюзных","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"(компания","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"песни","count":5}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"занимался","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"1979","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"лидии","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"убивали","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"города","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"наиболее","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"российский","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"(аск).","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"одним","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"(1958—1966)","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"1994","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"пластинку","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"вобщем","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"говорили","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"нашего","count":3}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"#зимняясказка","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"or","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"сможем","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"ила","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"москвы.","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"инициативе","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"фактор","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"павлу","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"оригинальной,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"13","count":14}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"1973).","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"написаны","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"редактор","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"20","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"создатель","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"получил","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"киностудий","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"арт-роковые","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"этапа","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"суде","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"известен","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"слюней","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"✅","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"будут","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"поэт,","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"согласие","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"избран","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"студией","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"делегаций","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"стран","count":3}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"summer","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"суть","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"«мансуровской»)","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"большом","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"любовь».","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"который","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"им.","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"лет.","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"родился","count":11}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"профессор.","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"2014","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"олигарх,","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"начать","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"1941","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"джохара","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"других.","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"театре.","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"восходят","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"футболках.","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"аналитик).","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"год","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"публицист,","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"шаферан,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"заместитель","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"федерации.","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"г.","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"„как","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"автор","count":5}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"пришли","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"давыдович","count":2}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"исследованиях","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":".","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"поэтому","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"технической","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"сюиты","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"мёрзнет","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"лилии","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"сценарист,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"5—6-го","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"арбитражном","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"текст.","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"лирическом","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"музыкальность,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"сторона»","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"директора","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"журналистом.","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"кладбище","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"документальном","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"часто","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"спине.","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"it's","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"года,","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"вдохновлена","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"внучкой","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"неменовой","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"андреевич","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"«круиз»,","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"дождаться","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"екатерине","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"справились!","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"(«с","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"особую","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"дня","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"просыпаюсь","count":2}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"with","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"несмотря","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"семье","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"исследовательской","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"епархией,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"общественной","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"сотрудничал","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"администрации","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"исполнял","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"ещё","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"свобода».","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"крылатыми.","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"всем","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"несколько","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"(первая","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"болельщиком","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"1769","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"большое","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"republican","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"бабрия).","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"носовая","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"сценаристом","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"android","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"созвездия","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"появилось","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"сон","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"«воскресение».","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"рапопорт.","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"\"посев\".","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"психиатрам...","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"года).","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"снегурочка","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"активность","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"(eju).","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"(высокий","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"восхищался.","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"заявление","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"григория","count":1}
# ...
# {"window":{"start":"2019-02-18T00:00:00.000Z","end":"2019-02-19T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"форум","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"островским","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"прошло","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"секторе,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"#gcam","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"эксперту","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"#snow","count":1}
# {"window":{"start":"2019-02-17T00:00:00.000Z","end":"2019-02-18T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"жертв","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"побывать","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"1903","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"авиаперевозках,","count":1}
# {"window":{"start":"2019-02-18T00:00:00.000Z","end":"2019-02-19T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"ожидайте","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"медийная","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"февраля.","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"россия\".","count":2}
# {"window":{"start":"2019-02-16T00:00:00.000Z","end":"2019-02-17T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"другим","count":1}
# {"window":{"start":"2019-02-15T00:00:00.000Z","end":"2019-02-16T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"игры!","count":1}
# {"window":{"start":"2019-02-15T00:00:00.000Z","end":"2019-02-16T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"поднимет","count":1}
# {"window":{"start":"2019-02-15T00:00:00.000Z","end":"2019-02-16T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"дает.","count":1}
# {"window":{"start":"2019-02-15T00:00:00.000Z","end":"2019-02-16T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"[club84179|aegee-moskva]","count":1}
# {"window":{"start":"2019-02-17T00:00:00.000Z","end":"2019-02-18T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"начале","count":3}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"носом","count":2}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"аркадием","count":1}
# {"window":{"start":"2019-02-15T00:00:00.000Z","end":"2019-02-16T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"ожидаемого","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"мотивации)","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"тухмановым.","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"спасибо","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"«бриллиантовый","count":1}
# {"window":{"start":"2019-02-17T00:00:00.000Z","end":"2019-02-18T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"созданный","count":1}
# {"window":{"start":"2019-02-21T00:00:00.000Z","end":"2019-02-22T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"почему","count":1}
# {"window":{"start":"2019-02-18T00:00:00.000Z","end":"2019-02-19T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"компания","count":1}
# {"window":{"start":"2019-02-17T00:00:00.000Z","end":"2019-02-18T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"отряд.","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"журналист,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"в.","count":2}
# {"window":{"start":"2019-02-15T00:00:00.000Z","end":"2019-02-16T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"расстройства","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"работой","count":1}
# {"window":{"start":"2019-02-15T00:00:00.000Z","end":"2019-02-16T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"java👨‍💻👩‍💻","count":1}
# {"window":{"start":"2019-02-15T00:00:00.000Z","end":"2019-02-16T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"(знакомых","count":1}
# {"window":{"start":"2019-02-18T00:00:00.000Z","end":"2019-02-19T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"ясно,","count":1}
# {"window":{"start":"2019-02-17T00:00:00.000Z","end":"2019-02-18T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"своего","count":1}
# {"window":{"start":"2019-02-17T00:00:00.000Z","end":"2019-02-18T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"мчс","count":1}
# {"window":{"start":"2019-02-21T00:00:00.000Z","end":"2019-02-22T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"больше,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"«альфа».","count":1}
# {"window":{"start":"2019-02-21T00:00:00.000Z","end":"2019-02-22T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"начать","count":1}
# {"window":{"start":"2019-02-16T00:00:00.000Z","end":"2019-02-17T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"2011","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"-","count":17}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"проявил","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"прекрасного","count":1}
# {"window":{"start":"2019-02-15T00:00:00.000Z","end":"2019-02-16T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"расслабляюсь.","count":1}
# {"window":{"start":"2019-02-16T00:00:00.000Z","end":"2019-02-17T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"войны,","count":1}
# {"window":{"start":"2019-02-16T00:00:00.000Z","end":"2019-02-17T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"втором","count":1}
# {"window":{"start":"2019-02-15T00:00:00.000Z","end":"2019-02-16T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"#подарок","count":1}
# {"window":{"start":"2019-02-19T00:00:00.000Z","end":"2019-02-20T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"моих","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"пугачёвой).","count":1}
# {"window":{"start":"2019-02-17T00:00:00.000Z","end":"2019-02-18T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"(1972—89).","count":1}
# {"window":{"start":"2019-02-21T00:00:00.000Z","end":"2019-02-22T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"задачи","count":1}
# {"window":{"start":"2019-02-19T00:00:00.000Z","end":"2019-02-20T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"группы","count":1}
# {"window":{"start":"2019-02-19T00:00:00.000Z","end":"2019-02-20T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"баку","count":2}
# {"window":{"start":"2019-02-17T00:00:00.000Z","end":"2019-02-18T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"русской","count":3}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"своих","count":1}
# {"window":{"start":"2019-02-17T00:00:00.000Z","end":"2019-02-18T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"(участник","count":1}
# {"window":{"start":"2019-02-21T00:00:00.000Z","end":"2019-02-22T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"осень","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"создании","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"#students","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"содействие","count":1}
# {"window":{"start":"2019-02-20T00:00:00.000Z","end":"2019-02-21T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"устал","count":1}
# {"window":{"start":"2019-02-17T00:00:00.000Z","end":"2019-02-18T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"1949","count":2}
# {"window":{"start":"2019-02-19T00:00:00.000Z","end":"2019-02-20T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"поставьте","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"1953).","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"нанесения.","count":1}
# {"window":{"start":"2019-02-15T00:00:00.000Z","end":"2019-02-16T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"нужен","count":1}
# {"window":{"start":"2019-02-15T00:00:00.000Z","end":"2019-02-16T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"всё","count":1}
# {"window":{"start":"2019-02-17T00:00:00.000Z","end":"2019-02-18T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"почта».","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"#february","count":1}
# {"window":{"start":"2019-02-17T00:00:00.000Z","end":"2019-02-18T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"мерзость👎🏻🌚😤🤧😾😠😡👿👺🔫","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"открыт","count":1}
# {"window":{"start":"2019-02-16T00:00:00.000Z","end":"2019-02-17T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"организации».","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"поэт","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"парк»","count":1}
# {"window":{"start":"2019-02-19T00:00:00.000Z","end":"2019-02-20T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"почтовую","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"странах","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"исполнитель","count":1}
# {"window":{"start":"2019-02-14T00:00:00.000Z","end":"2019-02-15T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"заполните","count":1}
# {"window":{"start":"2019-02-20T00:00:00.000Z","end":"2019-02-21T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"сигнатурные","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"театре,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"евгения","count":2}
# {"window":{"start":"2019-02-15T00:00:00.000Z","end":"2019-02-16T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"те,","count":1}
# {"window":{"start":"2019-02-13T00:00:00.000Z","end":"2019-02-14T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"юнеско","count":1}
# {"window":{"start":"2019-02-15T00:00:00.000Z","end":"2019-02-16T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"срывы","count":1}
# {"window":{"start":"2019-02-18T00:00:00.000Z","end":"2019-02-19T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"«зеленая","count":1}
# {"window":{"start":"2019-02-18T00:00:00.000Z","end":"2019-02-19T00:00:00.000Z"},"sex":"M","age_group":"18-27","word":"своим","count":1}
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# {"window":{"start":"2019-01-02T00:00:00.000Z","end":"2019-01-03T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":22}
# {"window":{"start":"2019-01-02T00:00:00.000Z","end":"2019-01-03T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":57}
# {"window":{"start":"2019-01-03T00:00:00.000Z","end":"2019-01-04T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":93}
# {"window":{"start":"2019-01-04T00:00:00.000Z","end":"2019-01-05T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":129}
# {"window":{"start":"2019-01-02T00:00:00.000Z","end":"2019-01-03T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":57}
# {"window":{"start":"2019-01-03T00:00:00.000Z","end":"2019-01-04T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":109}
# {"window":{"start":"2019-01-04T00:00:00.000Z","end":"2019-01-05T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":129}
# {"window":{"start":"2019-01-02T00:00:00.000Z","end":"2019-01-03T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":57}
# {"window":{"start":"2019-01-03T00:00:00.000Z","end":"2019-01-04T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":109}
# {"window":{"start":"2019-01-06T00:00:00.000Z","end":"2019-01-07T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":10}
# {"window":{"start":"2019-01-05T00:00:00.000Z","end":"2019-01-06T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":101}
# {"window":{"start":"2019-01-04T00:00:00.000Z","end":"2019-01-05T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":129}
# {"window":{"start":"2019-01-07T00:00:00.000Z","end":"2019-01-08T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":82}
# {"window":{"start":"2019-01-02T00:00:00.000Z","end":"2019-01-03T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":57}
# {"window":{"start":"2019-01-06T00:00:00.000Z","end":"2019-01-07T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":190}
# {"window":{"start":"2019-01-03T00:00:00.000Z","end":"2019-01-04T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":109}
# {"window":{"start":"2019-01-05T00:00:00.000Z","end":"2019-01-06T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":101}
# {"window":{"start":"2019-01-04T00:00:00.000Z","end":"2019-01-05T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":129}
# {"window":{"start":"2019-01-07T00:00:00.000Z","end":"2019-01-08T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":174}
# {"window":{"start":"2019-01-02T00:00:00.000Z","end":"2019-01-03T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":57}
# {"window":{"start":"2019-01-06T00:00:00.000Z","end":"2019-01-07T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":190}
# {"window":{"start":"2019-01-03T00:00:00.000Z","end":"2019-01-04T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":109}
# {"window":{"start":"2019-01-05T00:00:00.000Z","end":"2019-01-06T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":101}
# {"window":{"start":"2019-01-08T00:00:00.000Z","end":"2019-01-09T00:00:00.000Z"},"sex":"M","age_group":"18-27","count":152}
